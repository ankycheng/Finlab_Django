# %%
import sys,os
sys.path.append("..")
import django
django.setup()
import pandas as pd
from io import StringIO
import requests
import datetime
from crawlers.models import *
from crawlers.finlab.import_tools import *

# %%
class CrawlStockTiiTW:
    def __init__(self, date):
        self.date = date
        self.date_str = date.strftime("%Y%m%d")
        self.target_name = "台股三大法人個股買賣超資訊"
        self.sub_market = ["sii", "otc", "rotc"]

    def crawl_sii(self):
        r= requests.get('http://www.tse.com.tw/fund/T86?response=csv&date='+self.date_str+'&selectType=ALLBUT0999')
        try:
            df = pd.read_csv(StringIO(r.text), header=1).dropna(how='all', axis=1).dropna(how='any')
        except pd.errors.EmptyDataError:
            return None

        df = df.astype(str).apply(lambda s: s.str.replace(',',''))
        df['證券代號'] = df['證券代號'].str.replace('=','').str.replace('"','')
        df.iloc[:,2:]=df.iloc[:,2:].apply(lambda s: pd.to_numeric(s, errors='coerce')).dropna(how='all', axis=1)
        df =  df.rename(columns={'證券代號':'stock_id','證券名稱':'stock_name',
                                  '外陸資買進股數(不含外資自營商)':'fm_buy','外陸資賣出股數(不含外資自營商)':'fm_sell',
                                  '外陸資買賣超股數(不含外資自營商)':'fm_net','外資自營商買進股數':'fd_buy',
                                  '外資自營商賣出股數':'fd_sell','外資自營商買賣超股數':'fd_net',
                                  '投信買進股數':'itc_buy','投信賣出股數':'itc_sell',
                                  '投信買賣超股數':'itc_net','自營商買賣超股數':'dealer_net',
                                  '自營商買進股數(自行買賣)':'dealer_ppt_buy','自營商賣出股數(自行買賣)':'dealer_ppt_sell',
                                  '自營商買賣超股數(自行買賣)':'dealer_ppt_net','自營商買進股數(避險)':'dealer_hedge_buy',
                                  '自營商賣出股數(避險)':'dealer_hedge_sell','自營商買賣超股數(避險)':'dealer_hedge_net', 
                                  '三大法人買賣超股數':'tii_net'
        })
        df['ft_net']=df['fm_net']+df['fd_net']
        df["date"] = pd.to_datetime(self.date)
        return df
    
    def crawl_otc(self):

        y = str(int(self.date.strftime("%Y")) - 1911)
        date_str = y + "/" + self.date.strftime("%m") + "/" + self.date.strftime("%d")
        r = requests.get('http://www.tpex.org.tw/web/stock/3insti/daily_trade/3itrade_hedge_result.php?l=zh-tw&o=csv&se=EW&t=D&d='+date_str+'&s=0,asc')
        try:
            df = pd.read_csv(StringIO(r.text), header=1).dropna(how='all', axis=1).dropna(how='any')
        except pd.errors.ParserError:
            return None  
        df = df.astype(str).apply(lambda s: s.str.replace(',',''))
        df['代號'] = df['代號'].str.replace('=','').str.replace('"','')
        df.iloc[:,2:]=df.iloc[:,2:].apply(lambda s: pd.to_numeric(s, errors='coerce')).dropna(how='all', axis=1)
        df =  df.rename(columns={ '代號':'stock_id','名稱':'stock_name',
                                  '外資及陸資(不含外資自營商)-買進股數':'fm_buy','外資及陸資(不含外資自營商)-賣出股數':'fm_sell',
                                  '外資及陸資(不含外資自營商)-買賣超股數':'fm_net','外資自營商-買進股數':'fd_buy',
                                  '外資自營商-賣出股數':'fd_sell','外資自營商-買賣超股數':'fd_net',
                                  '投信-買進股數':'itc_buy','投信-賣出股數':'itc_sell',
                                  '投信-買賣超股數':'itc_net','自營商-買賣超股數':'dealer_net',
                                  '自營商(自行買賣)-買進股數':'dealer_ppt_buy','自營商(自行買賣)-賣出股數':'dealer_ppt_sell',
                                  '自營商(自行買賣)-買賣超股數':'dealer_ppt_net','自營商(避險)-買進股數':'dealer_hedge_buy',
                                  '自營商(避險)-賣出股數':'dealer_hedge_sell','自營商(避險)-買賣超股數':'dealer_hedge_net', 
                                  '三大法人買賣超股數合計':'tii_net'
        })
        df['ft_net']=df['fm_net']+df['fd_net']
        df=df.drop(columns=['外資及陸資-買進股數','外資及陸資-賣出股數','外資及陸資-買賣超股數','自營商-買進股數','自營商-賣出股數'])
        df["date"] = pd.to_datetime(self.date)

        return df

    def crawl_rotc(self):
        r = requests.get(
            'https://www.tpex.org.tw/web/emergingstock/historical/daily/EMDaily_dl.php?l=zh-tw&f=EMdss006.' + self.date_str + '-C.csv')
        try:
            df = pd.read_csv(StringIO(r.text), header=3).dropna(how='all', axis=1).dropna(how='any')
        except pd.errors.ParserError:
            return None
        df = df.drop(columns=['HEADER'])
        df = df.astype(str).apply(lambda s: s.str.replace(',', ''))
        df['證券代號'] = df['證券代號'].apply(lambda s: s[:4])
        df.iloc[:, 2:] = df.iloc[:, 2:].apply(lambda s: pd.to_numeric(s, errors='coerce')).dropna(how='all', axis=1)
        df = df.rename(columns={'證券代號': 'stock_id', '證券名稱': 'stock_name',
                                '外資(股數)': 'ft_net', '投信(股數)': 'itc_net',
                                '自營商(股數)': 'dealer_net', '合計買賣超(股數)': 'tii_net',

                                })

        df["date"] = pd.to_datetime(self.date)
        df['stock_id'] = df['stock_id'].apply(lambda s: s[:s.index(' ')] if '" "' in s else s)
        df['stock_name'] = df['stock_name'].apply(lambda s: s[:s.index(' ')] if '" "' in s else s)

        return df

    def crawl_main(self):
        try:
            df = pd.concat([self.crawl_sii(), self.crawl_otc(), self.crawl_rotc()], sort=False)
        except ValueError:
            return None
        return df
    

import datetime
df=CrawlStockTiiTW(datetime.datetime(2020,4,29)).crawl_main()
df
# Out:
#     stock_id            stock_name       fm_buy      fm_sell       fm_net  \
# 0       2303        聯電              6.21595e+07  1.34866e+07  4.86728e+07
# 1       2888         新光金            2.60063e+07  7.26003e+06  1.87463e+07
# 2       2454         聯發科            2.15998e+07  4.62757e+06  1.69722e+07
# 3       2330         台積電            3.38358e+07  1.83106e+07  1.55252e+07
# 4       3481        群創               3.1403e+07  1.74071e+07  1.39959e+07
# 5       2883         開發金             1.4206e+07   4.2456e+06   9.9604e+06
# 6       2884         玉山金            1.29602e+07  4.68761e+06  8.27258e+06
# 7       0056           元大高股息              35000        12000        23000
# 8       2882         國泰金             1.4607e+07  5.99154e+06  8.61546e+06
# 9       2881         富邦金             1.0222e+07    2.146e+06    8.076e+06
# 10      2603        長榮              6.56936e+06  2.35232e+06  4.21703e+06
# 11      2834         臺企銀            1.11942e+07  3.12573e+06  8.06848e+06
# 12      2002        中鋼              1.12836e+07  3.38863e+06  7.89497e+06
# 13      2324        仁寶                9.197e+06  1.81542e+06  7.38158e+06
# 14      5880         合庫金            1.04953e+07  3.54465e+06  6.95060e+06
# 15      2317        鴻海              1.63876e+07  1.05378e+07  5.84978e+06
# 16      2618         長榮航              1.163e+07  9.66608e+06  1.96392e+06
# 17      2892         第一金            1.14303e+07  5.28854e+06  6.14172e+06
# 18      2344         華邦電            8.64524e+06  3.71212e+06  4.93312e+06
# 19      0050          元大台灣50        3.83725e+06         2000  3.83525e+06
# 20      3037        欣興               1.3002e+07   1.3115e+07      -113000
# 21      2368         金像電              8.599e+06    5.047e+06    3.552e+06
# 22      2890         永豐金            8.19137e+06  3.36016e+06   4.8312e+06
# 23      9904        寶成                 7.61e+06  3.17141e+06  4.43859e+06
# 24      2823        中壽              5.86146e+06  1.39956e+06   4.4619e+06
# 25      3231        緯創              8.90855e+06  5.13927e+06  3.76928e+06
# 26      1303        南亞                5.101e+06  2.05244e+06  3.04856e+06
# 27      1101        台泥              9.44337e+06  5.11594e+06  4.32742e+06
# 28      2313        華通                3.768e+06    5.938e+06    -2.17e+06
# 29      2337        旺宏              9.93333e+06  7.94862e+06   1.9847e+06
# ..       ...                   ...          ...          ...          ...
# 617     8935                    邦泰         1000            0         1000
# 618     8936                    國統        10000       126000      -116000
# 619     8938                    明安        26000        25000         1000
# 620     8942                    森鉅        82000        87000        -5000
# 621     9949                    琉園        11000         1000        10000
# 622     9951                    皇田        40000        26000        14000
# 623   020001               富邦存股雙十N            0            0            0
# 624   020003            統一漲升股利150N            0            0            0
# 625   020010              永昌富櫃200N            0            0            0
# 626   020013              元富亞洲高股息N            0            0            0
# 627   020014              元大富櫃200N            0            0            0
# 0       1563    巧新                          NaN          NaN          NaN
# 1       2246      凱勝綠能                      NaN          NaN          NaN
# 2       3633    云光                          NaN          NaN          NaN
# 3       4151    明躍                          NaN          NaN          NaN
# 4       4195    基米                          NaN          NaN          NaN
# 5       4431    敏成                          NaN          NaN          NaN
# 6       4565    宏偉                          NaN          NaN          NaN
# 7       5222    全訊                          NaN          NaN          NaN
# 8       6595      光禹國際                      NaN          NaN          NaN
# 9       6598  ABC-KY                        NaN          NaN          NaN
# 10      6634    欣耀                          NaN          NaN          NaN
# 11      6645     金萬林                        NaN          NaN          NaN
# 12      6665      康聯生醫                      NaN          NaN          NaN
# 13      6692     進能服                        NaN          NaN          NaN
# 14      6732      昇佳電子                      NaN          NaN          NaN
# 15      6736     碩辣椒                        NaN          NaN          NaN
# 16      8119    公信                          NaN          NaN          NaN
# 17      8179    旭德                          NaN          NaN          NaN
# 18      8438    昶昕                          NaN          NaN          NaN
#
#     fd_buy fd_sell fd_net    itc_buy   itc_sell  ...   dealer_net  \
# 0        0       0      0  1.821e+06  3.361e+06  ...   -4.557e+06
# 1        0       0      0      80000          0  ...       250000
# 2        0       0      0     310000          0  ...      -341000
# 3        0       0      0     189000      20000  ...   -1.392e+06
# 4        0       0      0          0          0  ...      -652000
# 5        0       0      0  1.645e+06          0  ...      -320000
# 6        0       0      0      75000          0  ...       794000
# 7        0       0      0      49000          0  ...    8.514e+06
# 8        0       0      0      56000          0  ...      -504000
# 9        0       0      0      50000          0  ...      -173645
# 10       0       0      0  3.376e+06          0  ...       161000
# 11       0       0      0          0          0  ...      -469000
# 12       0       0      0      84000          0  ...      -602000
# 13       0       0      0       3000          0  ...      -694000
# 14       0       0      0      63000          0  ...      -343000
# 15       0       0      0     281000      40000  ...       111000
# 16       0       0      0  2.132e+06          0  ...    2.068e+06
# 17       0       0      0      67000      24000  ...      -387000
# 18       0       0      0          0          0  ...       384000
# 19       0       0      0     122000          0  ...    1.327e+06
# 20       0       0      0  3.519e+06      39000  ...    1.622e+06
# 21       0       0      0     170000      50000  ...    1.311e+06
# 22       0       0      0      71000          0  ...      -154000
# 23       0       0      0      18000          0  ...      -198000
# 24       0       0      0      19000          0  ...      -406000
# 25       0       0      0          0          0  ...       303000
# 26       0       0      0     798000          0  ...      -216000
# 27       0       0      0     558000  1.222e+06  ...      -150003
# 28       0       0      0  1.108e+06          0  ...     4.57e+06
# 29       0       0      0     427000     256000  ...  1.28689e+06
# ..     ...     ...    ...        ...        ...  ...          ...
# 617      0       0      0          0          0  ...            0
# 618      0       0      0          0          0  ...            0
# 619      0       0      0          0          0  ...            0
# 620      0       0      0          0          0  ...            0
# 621      0       0      0          0          0  ...            0
# 622      0       0      0          0          0  ...        -2000
# 623      0       0      0          0          0  ...       404000
# 624      0       0      0          0          0  ...        -1000
# 625      0       0      0          0          0  ...         1000
# 626      0       0      0          0          0  ...         1000
# 627      0       0      0          0          0  ...        28000
# 0      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 1      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 2      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 3      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 4      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 5      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 6      NaN     NaN    NaN        NaN        NaN  ...        -3000
# 7      NaN     NaN    NaN        NaN        NaN  ...        10000
# 8      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 9      NaN     NaN    NaN        NaN        NaN  ...          NaN
# 10     NaN     NaN    NaN        NaN        NaN  ...          NaN
# 11     NaN     NaN    NaN        NaN        NaN  ...          NaN
# 12     NaN     NaN    NaN        NaN        NaN  ...        30000
# 13     NaN     NaN    NaN        NaN        NaN  ...       -15000
# 14     NaN     NaN    NaN        NaN        NaN  ...          NaN
# 15     NaN     NaN    NaN        NaN        NaN  ...         5860
# 16     NaN     NaN    NaN        NaN        NaN  ...            4
# 17     NaN     NaN    NaN        NaN        NaN  ...        28494
# 18     NaN     NaN    NaN        NaN        NaN  ...        -6191
#
#     dealer_ppt_buy dealer_ppt_sell dealer_ppt_net dealer_hedge_buy  \
# 0             3000       1.698e+06     -1.695e+06           217000
# 1           192000           86000         106000           496000
# 2           357000          599000        -242000            47000
# 3            73000       1.154e+06     -1.081e+06           344000
# 4           553000          603000         -50000            22000
# 5             7000          708000        -701000           659000
# 6        1.136e+06          393000         743000            51000
# 7           130000               0         130000        9.278e+06
# 8            20000          408000        -388000            75000
# 9            58000          309000        -251000            88000
# 10          543000          382000         161000                0
# 11           25000          492000        -467000                0
# 12           44000          580000        -536000            50000
# 13           16000          332000        -316000                0
# 14           26000          394000        -368000            26000
# 15          273000          499000        -226000           419000
# 16       1.229e+06          357000         872000        1.236e+06
# 17           31000          426000        -395000            16000
# 18          429000          259000         170000           295000
# 19           10000               0          10000         3.66e+06
# 20       2.819e+06       2.197e+06         622000        1.327e+06
# 21       1.977e+06          781000      1.196e+06           157000
# 22          276000          422000        -146000                0
# 23           68000          266000        -198000                0
# 24               0          371000        -371000           112000
# 25          104000          193000         -89000           606000
# 26           15000          316000        -301000            85000
# 27           95000           91000           4000            54000
# 28       4.854e+06       1.196e+06      3.658e+06           948000
# 29          722000       1.246e+06        -524000      2.50489e+06
# ..             ...             ...            ...              ...
# 617              0               0              0                0
# 618              0               0              0                0
# 619              0               0              0                0
# 620              0               0              0                0
# 621              0               0              0                0
# 622              0               0              0                0
# 623              0               0              0           405000
# 624              0               0              0                0
# 625              0               0              0             2000
# 626              0               0              0             1000
# 627              0               0              0            41000
# 0              NaN             NaN            NaN              NaN
# 1              NaN             NaN            NaN              NaN
# 2              NaN             NaN            NaN              NaN
# 3              NaN             NaN            NaN              NaN
# 4              NaN             NaN            NaN              NaN
# 5              NaN             NaN            NaN              NaN
# 6              NaN             NaN            NaN              NaN
# 7              NaN             NaN            NaN              NaN
# 8              NaN             NaN            NaN              NaN
# 9              NaN             NaN            NaN              NaN
# 10             NaN             NaN            NaN              NaN
# 11             NaN             NaN            NaN              NaN
# 12             NaN             NaN            NaN              NaN
# 13             NaN             NaN            NaN              NaN
# 14             NaN             NaN            NaN              NaN
# 15             NaN             NaN            NaN              NaN
# 16             NaN             NaN            NaN              NaN
# 17             NaN             NaN            NaN              NaN
# 18             NaN             NaN            NaN              NaN
#
#     dealer_hedge_sell dealer_hedge_net      tii_net       ft_net       date
# 0           3.079e+06       -2.862e+06  4.25758e+07  4.86728e+07 2020-04-29
# 1              352000           144000  1.90763e+07  1.87463e+07 2020-04-29
# 2              146000           -99000  1.69412e+07  1.69722e+07 2020-04-29
# 3              655000          -311000  1.43022e+07  1.55252e+07 2020-04-29
# 4              624000          -602000  1.33439e+07  1.39959e+07 2020-04-29
# 5              278000           381000  1.12854e+07   9.9604e+06 2020-04-29
# 6                   0            51000  9.14158e+06  8.27258e+06 2020-04-29
# 7              894000        8.384e+06    8.586e+06        23000 2020-04-29
# 8              191000          -116000  8.16746e+06  8.61546e+06 2020-04-29
# 9               10645            77355  7.95236e+06    8.076e+06 2020-04-29
# 10                  0                0  7.75403e+06  4.21703e+06 2020-04-29
# 11               2000            -2000  7.59948e+06  8.06848e+06 2020-04-29
# 12             116000           -66000  7.37697e+06  7.89497e+06 2020-04-29
# 13             378000          -378000  6.69058e+06  7.38158e+06 2020-04-29
# 14               1000            25000  6.67060e+06  6.95060e+06 2020-04-29
# 15              82000           337000  6.20178e+06  5.84978e+06 2020-04-29
# 16              40000        1.196e+06  6.16392e+06  1.96392e+06 2020-04-29
# 17               8000             8000  5.79772e+06  6.14172e+06 2020-04-29
# 18              81000           214000  5.31712e+06  4.93312e+06 2020-04-29
# 19          2.343e+06        1.317e+06  5.28425e+06  3.83525e+06 2020-04-29
# 20             327000            1e+06    4.989e+06      -113000 2020-04-29
# 21              42000           115000    4.983e+06    3.552e+06 2020-04-29
# 22               8000            -8000   4.7482e+06   4.8312e+06 2020-04-29
# 23                  0                0  4.25859e+06  4.43859e+06 2020-04-29
# 24             147000           -35000   4.0749e+06   4.4619e+06 2020-04-29
# 25             214000           392000  4.07228e+06  3.76928e+06 2020-04-29
# 26                  0            85000  3.63056e+06  3.04856e+06 2020-04-29
# 27             208003          -154003  3.51342e+06  4.32742e+06 2020-04-29
# 28              36000           912000    3.508e+06    -2.17e+06 2020-04-29
# 29             694000      1.81089e+06   3.4426e+06   1.9847e+06 2020-04-29
# ..                ...              ...          ...          ...        ...
# 617                 0                0         1000         1000 2020-04-29
# 618                 0                0      -116000      -116000 2020-04-29
# 619                 0                0         1000         1000 2020-04-29
# 620                 0                0        -5000        -5000 2020-04-29
# 621                 0                0        10000        10000 2020-04-29
# 622              2000            -2000        12000        14000 2020-04-29
# 623              1000           404000       404000            0 2020-04-29
# 624              1000            -1000        -1000            0 2020-04-29
# 625              1000             1000         1000            0 2020-04-29
# 626                 0             1000         1000            0 2020-04-29
# 627             13000            28000        28000            0 2020-04-29
# 0                 NaN              NaN       -13965       -13965 2020-04-29
# 1                 NaN              NaN         1000         1000 2020-04-29
# 2                 NaN              NaN       -10000       -10000 2020-04-29
# 3                 NaN              NaN       -50000       -50000 2020-04-29
# 4                 NaN              NaN         3000         3000 2020-04-29
# 5                 NaN              NaN         3000         3000 2020-04-29
# 6                 NaN              NaN        -3000          NaN 2020-04-29
# 7                 NaN              NaN        10000          NaN 2020-04-29
# 8                 NaN              NaN       -28000       -28000 2020-04-29
# 9                 NaN              NaN       -21880       -21880 2020-04-29
# 10                NaN              NaN        -3000        -3000 2020-04-29
# 11                NaN              NaN         2000         2000 2020-04-29
# 12                NaN              NaN        30000          NaN 2020-04-29
# 13                NaN              NaN       -15000          NaN 2020-04-29
# 14                NaN              NaN        10310        10310 2020-04-29
# 15                NaN              NaN         5860          NaN 2020-04-29
# 16                NaN              NaN        15004        15000 2020-04-29
# 17                NaN              NaN        18494       -10000 2020-04-29
# 18                NaN              NaN        -6191          NaN 2020-04-29
#
# [1716 rows x 21 columns]

# %%
add_to_sql(StockTiiTW,df)
# Out:
# /Users/benbilly3/Finlab_Django/venv/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
# create  Stock_id:2303
# create  Stock_id:2888
# create  Stock_id:2454
# create  Stock_id:2330
# create  Stock_id:3481
# create  Stock_id:2883
# create  Stock_id:2884
# create  Stock_id:0056
# create  Stock_id:2882
# create  Stock_id:2881
# create  Stock_id:2603
# create  Stock_id:2834
# create  Stock_id:2002
# create  Stock_id:2324
# create  Stock_id:5880
# create  Stock_id:2317
# create  Stock_id:2618
# create  Stock_id:2892
# create  Stock_id:2344
# create  Stock_id:0050
# create  Stock_id:3037
# create  Stock_id:2368
# create  Stock_id:2890
# create  Stock_id:9904
# create  Stock_id:2823
# create  Stock_id:3231
# create  Stock_id:1303
# create  Stock_id:1101
# create  Stock_id:2313
# create  Stock_id:2337
# create  Stock_id:00852L
# create  Stock_id:1314
# create  Stock_id:4958
# create  Stock_id:1216
# create  Stock_id:2345
# create  Stock_id:2353
# create  Stock_id:1301
# create  Stock_id:1326
# create  Stock_id:1402
# create  Stock_id:3189
# create  Stock_id:00631L
# create  Stock_id:2363
# create  Stock_id:2867
# create  Stock_id:3006
# create  Stock_id:6505
# create  Stock_id:5871
# create  Stock_id:4938
# create  Stock_id:2408
# create  Stock_id:2371
# create  Stock_id:1515
# create  Stock_id:8046
# create  Stock_id:2412
# create  Stock_id:4956
# create  Stock_id:2845
# create  Stock_id:9921
# create  Stock_id:2504
# create  Stock_id:2367
# create  Stock_id:00850
# create  Stock_id:3682
# create  Stock_id:3576
# create  Stock_id:1907
# create  Stock_id:2332
# create  Stock_id:2379
# create  Stock_id:020012
# create  Stock_id:6153
# create  Stock_id:2049
# create  Stock_id:1605
# create  Stock_id:1714
# create  Stock_id:4414
# create  Stock_id:1609
# create  Stock_id:2201
# create  Stock_id:1102
# create  Stock_id:1802
# create  Stock_id:00673R
# create  Stock_id:2347
# create  Stock_id:2515
# create  Stock_id:2014
# create  Stock_id:9907
# create  Stock_id:5876
# create  Stock_id:2889
# create  Stock_id:2605
# create  Stock_id:2912
# create  Stock_id:00712
# create  Stock_id:6005
# create  Stock_id:2505
# create  Stock_id:2615
# create  Stock_id:5469
# create  Stock_id:6116
# create  Stock_id:3017
# create  Stock_id:6456
# create  Stock_id:2102
# create  Stock_id:2478
# create  Stock_id:1718
# create  Stock_id:3702
# create  Stock_id:1313
# create  Stock_id:9933
# create  Stock_id:2382
# create  Stock_id:2547
# create  Stock_id:5521
# create  Stock_id:2812
# create  Stock_id:6239
# create  Stock_id:1304
# create  Stock_id:2855
# create  Stock_id:00640L
# create  Stock_id:6531
# create  Stock_id:1762
# create  Stock_id:00692
# create  Stock_id:1305
# create  Stock_id:1308
# create  Stock_id:1210
# create  Stock_id:00875
# create  Stock_id:6191
# create  Stock_id:1455
# create  Stock_id:00653L
# create  Stock_id:2897
# create  Stock_id:1434
# create  Stock_id:2637
# create  Stock_id:3026
# create  Stock_id:3711
# create  Stock_id:2323
# create  Stock_id:2442
# create  Stock_id:2027
# create  Stock_id:2520
# create  Stock_id:1440
# create  Stock_id:3023
# create  Stock_id:2385
# create  Stock_id:1590
# create  Stock_id:1712
# create  Stock_id:2905
# create  Stock_id:2891
# create  Stock_id:1905
# create  Stock_id:00671R
# create  Stock_id:9910
# create  Stock_id:3019
# create  Stock_id:2836
# create  Stock_id:2809
# create  Stock_id:2392
# create  Stock_id:00693U
# create  Stock_id:2208
# create  Stock_id:3042
# create  Stock_id:3673
# create  Stock_id:2308
# create  Stock_id:2101
# create  Stock_id:2606
# create  Stock_id:2474
# create  Stock_id:2417
# create  Stock_id:2401
# create  Stock_id:2023
# create  Stock_id:1201
# create  Stock_id:2838
# create  Stock_id:2489
# create  Stock_id:1711
# create  Stock_id:2349
# create  Stock_id:4532
# create  Stock_id:6257
# create  Stock_id:5215
# create  Stock_id:3653
# create  Stock_id:1310
# create  Stock_id:00672L
# create  Stock_id:8404
# create  Stock_id:2614
# create  Stock_id:00730
# create  Stock_id:00635U
# create  Stock_id:6669
# create  Stock_id:2903
# create  Stock_id:1709
# create  Stock_id:2609
# create  Stock_id:2108
# create  Stock_id:2634
# create  Stock_id:1103
# create  Stock_id:5519
# create  Stock_id:3036
# create  Stock_id:2608
# create  Stock_id:2537
# create  Stock_id:00675L
# create  Stock_id:2357
# create  Stock_id:8081
# create  Stock_id:2206
# create  Stock_id:1447
# create  Stock_id:1444
# create  Stock_id:6443
# create  Stock_id:5607
# create  Stock_id:3533
# create  Stock_id:4133
# create  Stock_id:1611
# create  Stock_id:1522
# create  Stock_id:3376
# create  Stock_id:8996
# create  Stock_id:8039
# create  Stock_id:2375
# create  Stock_id:5531
# create  Stock_id:2207
# create  Stock_id:9935
# create  Stock_id:1701
# create  Stock_id:00654R
# create  Stock_id:1513
# create  Stock_id:6278
# create  Stock_id:4746
# create  Stock_id:00737
# create  Stock_id:4977
# create  Stock_id:2880
# create  Stock_id:00655L
# create  Stock_id:6504
# create  Stock_id:8028
# create  Stock_id:0061
# create  Stock_id:5269
# create  Stock_id:1795
# create  Stock_id:1604
# create  Stock_id:2485
# create  Stock_id:2107
# create  Stock_id:2923
# create  Stock_id:2841
# create  Stock_id:2939
# create  Stock_id:3406
# create  Stock_id:1708
# create  Stock_id:1789
# create  Stock_id:4725
# create  Stock_id:00861
# create  Stock_id:2388
# create  Stock_id:1338
# create  Stock_id:2511
# create  Stock_id:2404
# create  Stock_id:1608
# create  Stock_id:1477
# create  Stock_id:1309
# create  Stock_id:1476
# create  Stock_id:3661
# create  Stock_id:6209
# create  Stock_id:2439
# create  Stock_id:6668
# create  Stock_id:6139
# create  Stock_id:1319
# create  Stock_id:3665
# create  Stock_id:1417
# create  Stock_id:2031
# create  Stock_id:1536
# create  Stock_id:00701
# create  Stock_id:3596
# create  Stock_id:1902
# create  Stock_id:9941
# create  Stock_id:4904
# create  Stock_id:6592
# create  Stock_id:6141
# create  Stock_id:1519
# create  Stock_id:2456
# create  Stock_id:00647L
# create  Stock_id:1592
# create  Stock_id:2402
# create  Stock_id:2231
# create  Stock_id:1409
# create  Stock_id:00762
# create  Stock_id:1325
# create  Stock_id:2617
# create  Stock_id:2331
# create  Stock_id:6282
# create  Stock_id:2524
# create  Stock_id:2393
# create  Stock_id:2542
# create  Stock_id:2501
# create  Stock_id:1464
# create  Stock_id:1717
# create  Stock_id:4720
# create  Stock_id:3090
# create  Stock_id:8215
# create  Stock_id:1307
# create  Stock_id:00641R
# create  Stock_id:4564
# create  Stock_id:2030
# create  Stock_id:1460
# create  Stock_id:2342
# create  Stock_id:6120
# create  Stock_id:9934
# create  Stock_id:1217
# create  Stock_id:3014
# create  Stock_id:9802
# create  Stock_id:6452
# create  Stock_id:3038
# create  Stock_id:3504
# create  Stock_id:2707
# create  Stock_id:1810
# create  Stock_id:1104
# create  Stock_id:3056
# create  Stock_id:3532
# create  Stock_id:2457
# create  Stock_id:3059
# create  Stock_id:3708
# create  Stock_id:1227
# create  Stock_id:8110
# create  Stock_id:2421
# create  Stock_id:1316
# create  Stock_id:9925
# create  Stock_id:00651R
# create  Stock_id:00638R
# create  Stock_id:9911
# create  Stock_id:1220
# create  Stock_id:6024
# create  Stock_id:3356
# create  Stock_id:00766L
# create  Stock_id:2472
# create  Stock_id:2851
# create  Stock_id:3703
# create  Stock_id:1532
# create  Stock_id:1218
# create  Stock_id:4919
# create  Stock_id:2527
# create  Stock_id:1710
# create  Stock_id:1225
# create  Stock_id:00830
# create  Stock_id:00657
# create  Stock_id:2390
# create  Stock_id:00706L
# create  Stock_id:3060
# create  Stock_id:2006
# create  Stock_id:2850
# create  Stock_id:1720
# create  Stock_id:9917
# create  Stock_id:2852
# create  Stock_id:2015
# create  Stock_id:1457
# create  Stock_id:4106
# create  Stock_id:2816
# create  Stock_id:1612
# create  Stock_id:1702
# create  Stock_id:3047
# create  Stock_id:2467
# create  Stock_id:8105
# create  Stock_id:4526
# create  Stock_id:6165
# create  Stock_id:1734
# create  Stock_id:2062
# create  Stock_id:9940
# create  Stock_id:2704
# create  Stock_id:2514
# create  Stock_id:9908
# create  Stock_id:1231
# create  Stock_id:2723
# create  Stock_id:2832
# create  Stock_id:2022
# create  Stock_id:3003
# create  Stock_id:8016
# create  Stock_id:2413
# create  Stock_id:2109
# create  Stock_id:2929
# create  Stock_id:8926
# create  Stock_id:2461
# create  Stock_id:2010
# create  Stock_id:3563
# create  Stock_id:1808
# create  Stock_id:1806
# create  Stock_id:5258
# create  Stock_id:2642
# create  Stock_id:2539
# create  Stock_id:6177
# create  Stock_id:4961
# create  Stock_id:4142
# create  Stock_id:3712
# create  Stock_id:5007
# create  Stock_id:9930
# create  Stock_id:00752
# create  Stock_id:3312
# create  Stock_id:6277
# create  Stock_id:5285
# create  Stock_id:2405
# create  Stock_id:4766
# create  Stock_id:1108
# create  Stock_id:8454
# create  Stock_id:2355
# create  Stock_id:6142
# create  Stock_id:2849
# create  Stock_id:2705
# create  Stock_id:2545
# create  Stock_id:4942
# create  Stock_id:4989
# create  Stock_id:6235
# create  Stock_id:1473
# create  Stock_id:2013
# create  Stock_id:4552
# create  Stock_id:2506
# create  Stock_id:2535
# create  Stock_id:2612
# create  Stock_id:8463
# create  Stock_id:8341
# create  Stock_id:4536
# create  Stock_id:9924
# create  Stock_id:2007
# create  Stock_id:5608
# create  Stock_id:1614
# create  Stock_id:1337
# create  Stock_id:1459
# create  Stock_id:2204
# create  Stock_id:4994
# create  Stock_id:1446
# create  Stock_id:6224
# create  Stock_id:5234
# create  Stock_id:1906
# create  Stock_id:3041
# create  Stock_id:1474
# create  Stock_id:2913
# create  Stock_id:3028
# create  Stock_id:2009
# create  Stock_id:3050
# create  Stock_id:1442
# create  Stock_id:1503
# create  Stock_id:4141
# create  Stock_id:1321
# create  Stock_id:9937
# create  Stock_id:3645
# create  Stock_id:6605
# create  Stock_id:3024
# create  Stock_id:3321
# create  Stock_id:2701
# create  Stock_id:4968
# create  Stock_id:2486
# create  Stock_id:2548
# create  Stock_id:2908
# create  Stock_id:1560
# create  Stock_id:3062
# create  Stock_id:2239
# create  Stock_id:2227
# create  Stock_id:4306
# create  Stock_id:6112
# create  Stock_id:2538
# create  Stock_id:9943
# create  Stock_id:1109
# create  Stock_id:2607
# create  Stock_id:2020
# create  Stock_id:1528
# create  Stock_id:2702
# create  Stock_id:1733
# create  Stock_id:2450
# create  Stock_id:2706
# create  Stock_id:1773
# create  Stock_id:8429
# create  Stock_id:2028
# create  Stock_id:6491
# create  Stock_id:4967
# create  Stock_id:2374
# create  Stock_id:3705
# create  Stock_id:2348
# create  Stock_id:1229
# create  Stock_id:1419
# create  Stock_id:1737
# create  Stock_id:1339
# create  Stock_id:2429
# create  Stock_id:1514
# create  Stock_id:2012
# create  Stock_id:1723
# create  Stock_id:2034
# create  Stock_id:1340
# create  Stock_id:020000
# create  Stock_id:2731
# create  Stock_id:2528
# create  Stock_id:8131
# create  Stock_id:2633
# create  Stock_id:9927
# create  Stock_id:0055
# create  Stock_id:1731
# create  Stock_id:2069
# create  Stock_id:6672
# create  Stock_id:8462
# create  Stock_id:2017
# create  Stock_id:6552
# create  Stock_id:4916
# create  Stock_id:4930
# create  Stock_id:00728
# create  Stock_id:1451
# create  Stock_id:2359
# create  Stock_id:2480
# create  Stock_id:1203
# create  Stock_id:8261
# create  Stock_id:00713
# create  Stock_id:2423
# create  Stock_id:4566
# create  Stock_id:2739
# create  Stock_id:6197
# create  Stock_id:00663L
# create  Stock_id:3058
# create  Stock_id:00680L
# create  Stock_id:2228
# create  Stock_id:4155
# create  Stock_id:5534
# create  Stock_id:02001L
# create  Stock_id:2395
# create  Stock_id:3209
# create  Stock_id:6184
# create  Stock_id:2477
# create  Stock_id:9955
# create  Stock_id:2351
# create  Stock_id:1903
# create  Stock_id:4906
# create  Stock_id:2459
# create  Stock_id:3052
# create  Stock_id:3057
# create  Stock_id:2365
# create  Stock_id:2911
# create  Stock_id:3022
# create  Stock_id:2530
# create  Stock_id:8101
# create  Stock_id:3266
# create  Stock_id:1616
# create  Stock_id:6115
# create  Stock_id:00661
# create  Stock_id:1315
# create  Stock_id:2906
# create  Stock_id:1615
# create  Stock_id:1783
# create  Stock_id:3035
# create  Stock_id:6715
# create  Stock_id:5525
# create  Stock_id:5305
# create  Stock_id:3040
# create  Stock_id:2483
# create  Stock_id:1726
# create  Stock_id:4576
# create  Stock_id:2540
# create  Stock_id:3013
# create  Stock_id:3094
# create  Stock_id:2498
# create  Stock_id:1517
# create  Stock_id:1454
# create  Stock_id:6283
# create  Stock_id:1416
# create  Stock_id:6449
# create  Stock_id:4426
# create  Stock_id:1414
# create  Stock_id:1713
# create  Stock_id:2611
# create  Stock_id:3694
# create  Stock_id:1537
# create  Stock_id:8033
# create  Stock_id:1524
# create  Stock_id:2497
# create  Stock_id:1521
# create  Stock_id:2373
# create  Stock_id:1219
# create  Stock_id:4555
# create  Stock_id:1603
# create  Stock_id:8411
# create  Stock_id:2516
# create  Stock_id:2114
# create  Stock_id:1436
# create  Stock_id:6541
# create  Stock_id:6215
# create  Stock_id:2305
# create  Stock_id:5283
# create  Stock_id:1452
# create  Stock_id:020008
# create  Stock_id:1529
# create  Stock_id:2509
# create  Stock_id:3015
# create  Stock_id:00770
# create  Stock_id:2414
# create  Stock_id:4190
# create  Stock_id:2597
# create  Stock_id:2460
# create  Stock_id:00783
# create  Stock_id:2462
# create  Stock_id:2630
# create  Stock_id:00690
# create  Stock_id:4104
# create  Stock_id:1721
# create  Stock_id:2543
# create  Stock_id:3501
# create  Stock_id:00703
# create  Stock_id:6206
# create  Stock_id:1618
# create  Stock_id:2440
# create  Stock_id:00645
# create  Stock_id:6477
# create  Stock_id:3257
# create  Stock_id:3305
# create  Stock_id:1809
# create  Stock_id:8473
# create  Stock_id:1432
# create  Stock_id:2433
# create  Stock_id:2427
# create  Stock_id:1449
# create  Stock_id:6216
# create  Stock_id:3055
# create  Stock_id:2038
# create  Stock_id:2302
# create  Stock_id:3032
# create  Stock_id:2882A
# create  Stock_id:6108
# create  Stock_id:1235
# create  Stock_id:2838A
# create  Stock_id:1535
# create  Stock_id:5284
# create  Stock_id:4144
# create  Stock_id:4722
# create  Stock_id:4438
# create  Stock_id:9926
# create  Stock_id:2358
# create  Stock_id:8464
# create  Stock_id:2476
# create  Stock_id:1540
# create  Stock_id:2613
# create  Stock_id:2397
# create  Stock_id:6581
# create  Stock_id:5706
# create  Stock_id:1445
# create  Stock_id:3494
# create  Stock_id:1786
# create  Stock_id:6133
# create  Stock_id:4912
# create  Stock_id:8114
# create  Stock_id:4164
# create  Stock_id:1467
# create  Stock_id:6205
# create  Stock_id:6579
# create  Stock_id:3164
# create  Stock_id:3701
# create  Stock_id:00682U
# create  Stock_id:4562
# create  Stock_id:2032
# create  Stock_id:5533
# create  Stock_id:1413
# create  Stock_id:2910
# create  Stock_id:3167
# create  Stock_id:6189
# create  Stock_id:8249
# create  Stock_id:4545
# create  Stock_id:1463
# create  Stock_id:5538
# create  Stock_id:2419
# create  Stock_id:6128
# create  Stock_id:3622
# create  Stock_id:3030
# create  Stock_id:6164
# create  Stock_id:2471
# create  Stock_id:00668
# create  Stock_id:8072
# create  Stock_id:6409
# create  Stock_id:2748
# create  Stock_id:9931
# create  Stock_id:1443
# create  Stock_id:1533
# create  Stock_id:9918
# create  Stock_id:2443
# create  Stock_id:4763
# create  Stock_id:2546
# create  Stock_id:6525
# create  Stock_id:3011
# create  Stock_id:00684R
# create  Stock_id:1568
# create  Stock_id:4976
# create  Stock_id:2466
# create  Stock_id:1626
# create  Stock_id:1582
# create  Stock_id:4952
# create  Stock_id:2115
# create  Stock_id:8480
# create  Stock_id:6152
# create  Stock_id:1617
# create  Stock_id:6117
# create  Stock_id:8478
# create  Stock_id:3583
# create  Stock_id:1530
# create  Stock_id:3025
# create  Stock_id:2033
# create  Stock_id:6183
# create  Stock_id:1724
# create  Stock_id:00685L
# create  Stock_id:1456
# create  Stock_id:2465
# create  Stock_id:1435
# create  Stock_id:9103
# create  Stock_id:3027
# create  Stock_id:3550
# create  Stock_id:1727
# create  Stock_id:6136
# create  Stock_id:00731
# create  Stock_id:3004
# create  Stock_id:1725
# create  Stock_id:1817
# create  Stock_id:2444
# create  Stock_id:1236
# create  Stock_id:9929
# create  Stock_id:3002
# create  Stock_id:01003T
# create  Stock_id:1466
# create  Stock_id:2482
# create  Stock_id:3528
# create  Stock_id:8222
# create  Stock_id:1558
# create  Stock_id:1441
# create  Stock_id:1110
# create  Stock_id:3033
# create  Stock_id:1465
# create  Stock_id:8201
# create  Stock_id:2636
# create  Stock_id:1423
# create  Stock_id:3416
# create  Stock_id:4572
# create  Stock_id:8367
# create  Stock_id:2438
# create  Stock_id:3296
# create  Stock_id:9906
# create  Stock_id:6168
# create  Stock_id:01007T
# create  Stock_id:6281
# create  Stock_id:5484
# create  Stock_id:2616
# create  Stock_id:6201
# create  Stock_id:2488
# create  Stock_id:1453
# create  Stock_id:1256
# create  Stock_id:1233
# create  Stock_id:1323
# create  Stock_id:4571
# create  Stock_id:1583
# create  Stock_id:6674
# create  Stock_id:6671
# create  Stock_id:3591
# create  Stock_id:00683L
# create  Stock_id:2722
# create  Stock_id:3383
# create  Stock_id:2901
# create  Stock_id:6591
# create  Stock_id:1587
# create  Stock_id:4999
# create  Stock_id:6243
# create  Stock_id:1539
# create  Stock_id:6442
# create  Stock_id:3432
# create  Stock_id:8443
# create  Stock_id:3593
# create  Stock_id:6405
# create  Stock_id:9912
# create  Stock_id:4557
# create  Stock_id:2468
# create  Stock_id:1468
# create  Stock_id:6573
# create  Stock_id:2904
# create  Stock_id:3054
# create  Stock_id:6655
# create  Stock_id:3229
# create  Stock_id:2936
# create  Stock_id:4148
# create  Stock_id:6698
# create  Stock_id:1589
# create  Stock_id:9902
# create  Stock_id:8103
# create  Stock_id:2024
# create  Stock_id:8442
# create  Stock_id:1735
# create  Stock_id:4755
# create  Stock_id:2415
# create  Stock_id:1410
# create  Stock_id:6431
# create  Stock_id:2881A
# create  Stock_id:00742
# create  Stock_id:2436
# create  Stock_id:1541
# create  Stock_id:1776
# create  Stock_id:1312A
# create  Stock_id:00688L
# create  Stock_id:4807
# create  Stock_id:2887E
# create  Stock_id:2233
# create  Stock_id:1324
# create  Stock_id:00733
# create  Stock_id:3021
# create  Stock_id:4560
# create  Stock_id:00851
# create  Stock_id:3535
# create  Stock_id:3130
# create  Stock_id:0052
# create  Stock_id:2712
# create  Stock_id:4439
# create  Stock_id:1526
# create  Stock_id:8481
# create  Stock_id:006204
# create  Stock_id:4764
# create  Stock_id:1438
# create  Stock_id:8427
# create  Stock_id:00707R
# create  Stock_id:00866
# create  Stock_id:2002A
# create  Stock_id:2236
# create  Stock_id:2008
# create  Stock_id:00776
# create  Stock_id:9941A
# create  Stock_id:1516
# create  Stock_id:6464
# create  Stock_id:020004
# create  Stock_id:6625
# create  Stock_id:8488
# create  Stock_id:3048
# create  Stock_id:8466
# create  Stock_id:8467
# create  Stock_id:6641
# create  Stock_id:00678
# create  Stock_id:1470
# create  Stock_id:2424
# create  Stock_id:0057
# create  Stock_id:3308
# create  Stock_id:8374
# create  Stock_id:1805
# create  Stock_id:0054
# create  Stock_id:8497
# create  Stock_id:2881B
# create  Stock_id:3346
# create  Stock_id:5906
# create  Stock_id:6666
# create  Stock_id:00732
# create  Stock_id:6192
# create  Stock_id:00775B
# create  Stock_id:00636K
# create  Stock_id:00668K
# create  Stock_id:0053
# create  Stock_id:00625K
# create  Stock_id:00657K
# create  Stock_id:6172
# create  Stock_id:00666R
# create  Stock_id:00774B
# create  Stock_id:1232
# create  Stock_id:1525
# create  Stock_id:020016
# create  Stock_id:00767
# create  Stock_id:9105
# create  Stock_id:00709
# create  Stock_id:9110
# create  Stock_id:00735
# create  Stock_id:3679
# create  Stock_id:2727
# create  Stock_id:2425
# create  Stock_id:020011
# create  Stock_id:5515
# create  Stock_id:4551
# create  Stock_id:0051
# create  Stock_id:8070
# create  Stock_id:2243
# create  Stock_id:1730
# create  Stock_id:9942
# create  Stock_id:01004T
# create  Stock_id:006206
# create  Stock_id:00865B
# create  Stock_id:2029
# create  Stock_id:910322
# create  Stock_id:8940
# create  Stock_id:2496
# create  Stock_id:2491
# create  Stock_id:00711B
# create  Stock_id:00763U
# create  Stock_id:2430
# create  Stock_id:00700
# create  Stock_id:8482
# create  Stock_id:3607
# create  Stock_id:020015
# create  Stock_id:2431
# create  Stock_id:00656R
# create  Stock_id:1437
# create  Stock_id:00757
# create  Stock_id:1531
# create  Stock_id:5225
# create  Stock_id:00665L
# create  Stock_id:00702
# create  Stock_id:5907
# create  Stock_id:2428
# create  Stock_id:2420
# create  Stock_id:3149
# create  Stock_id:01002T
# create  Stock_id:006207
# create  Stock_id:6166
# create  Stock_id:2377
# create  Stock_id:2887F
# create  Stock_id:3008
# create  Stock_id:2362
# create  Stock_id:00674R
# create  Stock_id:1598
# create  Stock_id:8422
# create  Stock_id:2495
# create  Stock_id:00736
# create  Stock_id:3031
# create  Stock_id:3010
# create  Stock_id:5288
# create  Stock_id:1234
# create  Stock_id:2536
# create  Stock_id:00714
# create  Stock_id:00681R
# create  Stock_id:910861
# create  Stock_id:9905
# create  Stock_id:2441
# create  Stock_id:3454
# create  Stock_id:9946
# create  Stock_id:3669
# create  Stock_id:2887
# create  Stock_id:2820
# create  Stock_id:6706
# create  Stock_id:00771
# create  Stock_id:00652
# create  Stock_id:00660
# create  Stock_id:2493
# create  Stock_id:1439
# create  Stock_id:4737
# create  Stock_id:4119
# create  Stock_id:6226
# create  Stock_id:3686
# create  Stock_id:8499
# create  Stock_id:5522
# create  Stock_id:2399
# create  Stock_id:9136
# create  Stock_id:4540
# create  Stock_id:2453
# create  Stock_id:3311
# create  Stock_id:9945
# create  Stock_id:2360
# create  Stock_id:1507
# create  Stock_id:02001R
# create  Stock_id:2882B
# create  Stock_id:1527
# create  Stock_id:00689R
# create  Stock_id:5243
# create  Stock_id:006208
# create  Stock_id:2484
# create  Stock_id:4137
# create  Stock_id:00753L
# create  Stock_id:5434
# create  Stock_id:3617
# create  Stock_id:2380
# create  Stock_id:1732
# create  Stock_id:3413
# create  Stock_id:9188
# create  Stock_id:6533
# create  Stock_id:1707
# create  Stock_id:00650L
# create  Stock_id:2354
# create  Stock_id:5388
# create  Stock_id:3557
# create  Stock_id:006205
# create  Stock_id:4915
# create  Stock_id:5203
# create  Stock_id:3419
# create  Stock_id:9958
# create  Stock_id:6670
# create  Stock_id:00636
# create  Stock_id:2338
# create  Stock_id:6230
# create  Stock_id:2059
# create  Stock_id:6412
# create  Stock_id:3049
# create  Stock_id:3450
# create  Stock_id:2464
# create  Stock_id:6451
# create  Stock_id:3605
# create  Stock_id:9919
# create  Stock_id:6415
# create  Stock_id:6214
# create  Stock_id:8104
# create  Stock_id:3518
# create  Stock_id:8210
# create  Stock_id:1215
# create  Stock_id:4960
# create  Stock_id:6213
# create  Stock_id:6582
# create  Stock_id:2534
# create  Stock_id:2314
# create  Stock_id:1312
# create  Stock_id:3437
# create  Stock_id:00738U
# create  Stock_id:6285
# create  Stock_id:8213
# create  Stock_id:2915
# create  Stock_id:8021
# create  Stock_id:1760
# create  Stock_id:3016
# create  Stock_id:6196
# create  Stock_id:8011
# create  Stock_id:4108
# create  Stock_id:2312
# create  Stock_id:00646
# create  Stock_id:2451
# create  Stock_id:00739
# create  Stock_id:4739
# create  Stock_id:9944
# create  Stock_id:2340
# create  Stock_id:4943
# create  Stock_id:8271
# create  Stock_id:6155
# create  Stock_id:3588
# create  Stock_id:3018
# create  Stock_id:00710B
# create  Stock_id:6414
# create  Stock_id:00639
# create  Stock_id:2316
# create  Stock_id:5264
# create  Stock_id:6416
# create  Stock_id:8163
# create  Stock_id:9939
# create  Stock_id:1504
# create  Stock_id:3704
# create  Stock_id:00634R
# create  Stock_id:5471
# create  Stock_id:00717
# create  Stock_id:2383
# create  Stock_id:6288
# create  Stock_id:1722
# create  Stock_id:3515
# create  Stock_id:8150
# create  Stock_id:2328
# create  Stock_id:2455
# create  Stock_id:2801
# create  Stock_id:6271
# create  Stock_id:1904
# create  Stock_id:3005
# create  Stock_id:00643
# create  Stock_id:3380
# create  Stock_id:4935
# create  Stock_id:2105
# create  Stock_id:1736
# create  Stock_id:9938
# create  Stock_id:2406
# create  Stock_id:00633L
# create  Stock_id:6202
# create  Stock_id:00670L
# create  Stock_id:9914
# create  Stock_id:00686R
# create  Stock_id:2301
# create  Stock_id:2481
# create  Stock_id:3034
# create  Stock_id:2885
# create  Stock_id:3029
# create  Stock_id:3443
# create  Stock_id:2106
# create  Stock_id:2610
# create  Stock_id:3706
# create  Stock_id:3530
# create  Stock_id:3044
# create  Stock_id:2352
# create  Stock_id:00662
# create  Stock_id:00648R
# create  Stock_id:2387
# create  Stock_id:4927
# create  Stock_id:1909
# create  Stock_id:8112
# create  Stock_id:3545
# create  Stock_id:2376
# create  Stock_id:2426
# create  Stock_id:6558
# create  Stock_id:3698
# create  Stock_id:2103
# create  Stock_id:2369
# create  Stock_id:2104
# create  Stock_id:4934
# create  Stock_id:2601
# create  Stock_id:00669R
# create  Stock_id:2329
# create  Stock_id:00715L
# create  Stock_id:3338
# create  Stock_id:2356
# create  Stock_id:00708L
# create  Stock_id:00637L
# create  Stock_id:2449
# create  Stock_id:3045
# create  Stock_id:2492
# create  Stock_id:6251
# create  Stock_id:2458
# create  Stock_id:00676R
# create  Stock_id:00664R
# create  Stock_id:6176
# create  Stock_id:2886
# create  Stock_id:2448
# create  Stock_id:2327
# create  Stock_id:6269
# create  Stock_id:2409
# create  Stock_id:00642U
# create  Stock_id:00677U
# create  Stock_id:00632R
# create  Stock_id:00679B
# create  Stock_id:00687B
# create  Stock_id:00694B
# create  Stock_id:00695B
# create  Stock_id:00696B
# create  Stock_id:00697B
# create  Stock_id:00718B
# create  Stock_id:00719B
# create  Stock_id:00720B
# create  Stock_id:00721B
# create  Stock_id:00722B
# create  Stock_id:00723B
# create  Stock_id:00724B
# create  Stock_id:00725B
# create  Stock_id:00726B
# create  Stock_id:00727B
# create  Stock_id:00734B
# create  Stock_id:00740B
# create  Stock_id:00741B
# create  Stock_id:00744B
# create  Stock_id:00745B
# create  Stock_id:00746B
# create  Stock_id:00747B
# create  Stock_id:00748B
# create  Stock_id:00749B
# create  Stock_id:00750B
# create  Stock_id:00751B
# create  Stock_id:00754B
# create  Stock_id:00755B
# create  Stock_id:00756B
# create  Stock_id:00758B
# create  Stock_id:00759B
# create  Stock_id:00760B
# create  Stock_id:00761B
# create  Stock_id:00764B
# create  Stock_id:00765B
# create  Stock_id:00768B
# create  Stock_id:00769B
# create  Stock_id:00772B
# create  Stock_id:00773B
# create  Stock_id:00777B
# create  Stock_id:00779B
# create  Stock_id:00780B
# create  Stock_id:00781B
# create  Stock_id:00782B
# create  Stock_id:00784B
# create  Stock_id:00785B
# create  Stock_id:00786B
# create  Stock_id:00787B
# create  Stock_id:00788B
# create  Stock_id:00789B
# create  Stock_id:00790B
# create  Stock_id:00791B
# create  Stock_id:00792B
# create  Stock_id:00793B
# create  Stock_id:00794B
# create  Stock_id:00795B
# create  Stock_id:00796B
# create  Stock_id:00797B
# create  Stock_id:00798B
# create  Stock_id:00799B
# create  Stock_id:00831B
# create  Stock_id:00832B
# create  Stock_id:00833B
# create  Stock_id:00834B
# create  Stock_id:00835B
# create  Stock_id:00836B
# create  Stock_id:00837B
# create  Stock_id:00838B
# create  Stock_id:00839B
# create  Stock_id:00840B
# create  Stock_id:00841B
# create  Stock_id:00842B
# create  Stock_id:00843B
# create  Stock_id:00844B
# create  Stock_id:00845B
# create  Stock_id:00846B
# create  Stock_id:00847B
# create  Stock_id:00848B
# create  Stock_id:00849B
# create  Stock_id:00854B
# create  Stock_id:00855B
# create  Stock_id:00856B
# create  Stock_id:00857B
# create  Stock_id:00858
# create  Stock_id:00859B
# create  Stock_id:00860B
# create  Stock_id:00862B
# create  Stock_id:00863B
# create  Stock_id:00864B
# create  Stock_id:00867B
# create  Stock_id:00868B
# create  Stock_id:00869B
# create  Stock_id:00870B
# create  Stock_id:00871B
# create  Stock_id:00872B
# create  Stock_id:00873B
# create  Stock_id:00874B
# create  Stock_id:1240
# create  Stock_id:1264
# create  Stock_id:1268
# create  Stock_id:1336
# create  Stock_id:1565
# create  Stock_id:1569
# create  Stock_id:1580
# create  Stock_id:1584
# create  Stock_id:1586
# create  Stock_id:1597
# create  Stock_id:1599
# create  Stock_id:1742
# create  Stock_id:1752
# create  Stock_id:1777
# create  Stock_id:1781
# create  Stock_id:1784
# create  Stock_id:1785
# create  Stock_id:1788
# create  Stock_id:1799
# create  Stock_id:1815
# create  Stock_id:2035
# create  Stock_id:2061
# create  Stock_id:2065
# create  Stock_id:2067
# create  Stock_id:2070
# create  Stock_id:2221
# create  Stock_id:2596
# create  Stock_id:2640
# create  Stock_id:2641
# create  Stock_id:2643
# create  Stock_id:2726
# create  Stock_id:2729
# create  Stock_id:2732
# create  Stock_id:2736
# create  Stock_id:2743
# create  Stock_id:2928
# create  Stock_id:3067
# create  Stock_id:3071
# create  Stock_id:3078
# create  Stock_id:3081
# create  Stock_id:3083
# create  Stock_id:3088
# create  Stock_id:3092
# create  Stock_id:3105
# create  Stock_id:3118
# create  Stock_id:3122
# create  Stock_id:3131
# create  Stock_id:3141
# create  Stock_id:3144
# create  Stock_id:3147
# create  Stock_id:3152
# create  Stock_id:3163
# create  Stock_id:3169
# create  Stock_id:3171
# create  Stock_id:3176
# create  Stock_id:3178
# create  Stock_id:3191
# create  Stock_id:3202
# create  Stock_id:3205
# create  Stock_id:3206
# create  Stock_id:3211
# create  Stock_id:3213
# create  Stock_id:3217
# create  Stock_id:3218
# create  Stock_id:3221
# create  Stock_id:3224
# create  Stock_id:3227
# create  Stock_id:3228
# create  Stock_id:3232
# create  Stock_id:3234
# create  Stock_id:3236
# create  Stock_id:3252
# create  Stock_id:3259
# create  Stock_id:3260
# create  Stock_id:3264
# create  Stock_id:3265
# create  Stock_id:3268
# create  Stock_id:3272
# create  Stock_id:3284
# create  Stock_id:3285
# create  Stock_id:3289
# create  Stock_id:3290
# create  Stock_id:3293
# create  Stock_id:3303
# create  Stock_id:3313
# create  Stock_id:3317
# create  Stock_id:3322
# create  Stock_id:3323
# create  Stock_id:3324
# create  Stock_id:3354
# create  Stock_id:3360
# create  Stock_id:3362
# create  Stock_id:3363
# create  Stock_id:3372
# create  Stock_id:3373
# create  Stock_id:3374
# create  Stock_id:3388
# create  Stock_id:3390
# create  Stock_id:3402
# create  Stock_id:3438
# create  Stock_id:3441
# create  Stock_id:3444
# create  Stock_id:3455
# create  Stock_id:3466
# create  Stock_id:3479
# create  Stock_id:3483
# create  Stock_id:3484
# create  Stock_id:3489
# create  Stock_id:3490
# create  Stock_id:3491
# create  Stock_id:3492
# create  Stock_id:3498
# create  Stock_id:3499
# create  Stock_id:3508
# create  Stock_id:3511
# create  Stock_id:3520
# create  Stock_id:3521
# create  Stock_id:3522
# create  Stock_id:3526
# create  Stock_id:3527
# create  Stock_id:3529
# create  Stock_id:3531
# create  Stock_id:3537
# create  Stock_id:3540
# create  Stock_id:3541
# create  Stock_id:3546
# create  Stock_id:3548
# create  Stock_id:3551
# create  Stock_id:3552
# create  Stock_id:3556
# create  Stock_id:3558
# create  Stock_id:3570
# create  Stock_id:3577
# create  Stock_id:3580
# create  Stock_id:3587
# create  Stock_id:3594
# create  Stock_id:3609
# create  Stock_id:3611
# create  Stock_id:3623
# create  Stock_id:3624
# create  Stock_id:3625
# create  Stock_id:3628
# create  Stock_id:3630
# create  Stock_id:3631
# create  Stock_id:3632
# create  Stock_id:3642
# create  Stock_id:3666
# create  Stock_id:3675
# create  Stock_id:3680
# create  Stock_id:3684
# create  Stock_id:3685
# create  Stock_id:3687
# create  Stock_id:3689
# create  Stock_id:3691
# create  Stock_id:3707
# create  Stock_id:3709
# create  Stock_id:3710
# create  Stock_id:4102
# create  Stock_id:4105
# create  Stock_id:4107
# create  Stock_id:4109
# create  Stock_id:4111
# create  Stock_id:4113
# create  Stock_id:4114
# create  Stock_id:4116
# create  Stock_id:4120
# create  Stock_id:4121
# create  Stock_id:4123
# create  Stock_id:4126
# create  Stock_id:4128
# create  Stock_id:4130
# create  Stock_id:4147
# create  Stock_id:4152
# create  Stock_id:4153
# create  Stock_id:4157
# create  Stock_id:4161
# create  Stock_id:4162
# create  Stock_id:4163
# create  Stock_id:4167
# create  Stock_id:4168
# create  Stock_id:4171
# create  Stock_id:4173
# create  Stock_id:4174
# create  Stock_id:4192
# create  Stock_id:4401
# create  Stock_id:4417
# create  Stock_id:4420
# create  Stock_id:4430
# create  Stock_id:4432
# create  Stock_id:4433
# create  Stock_id:4503
# create  Stock_id:4506
# create  Stock_id:4510
# create  Stock_id:4513
# create  Stock_id:4523
# create  Stock_id:4527
# create  Stock_id:4528
# create  Stock_id:4530
# create  Stock_id:4533
# create  Stock_id:4534
# create  Stock_id:4541
# create  Stock_id:4549
# create  Stock_id:4550
# create  Stock_id:4554
# create  Stock_id:4561
# create  Stock_id:4563
# create  Stock_id:4580
# create  Stock_id:4702
# create  Stock_id:4707
# create  Stock_id:4714
# create  Stock_id:4716
# create  Stock_id:4721
# create  Stock_id:4726
# create  Stock_id:4728
# create  Stock_id:4729
# create  Stock_id:4735
# create  Stock_id:4736
# create  Stock_id:4743
# create  Stock_id:4744
# create  Stock_id:4745
# create  Stock_id:4747
# create  Stock_id:4760
# create  Stock_id:4803
# create  Stock_id:4907
# create  Stock_id:4908
# create  Stock_id:4909
# create  Stock_id:4911
# create  Stock_id:4924
# create  Stock_id:4931
# create  Stock_id:4933
# create  Stock_id:4939
# create  Stock_id:4946
# create  Stock_id:4947
# create  Stock_id:4953
# create  Stock_id:4966
# create  Stock_id:4971
# create  Stock_id:4973
# create  Stock_id:4974
# create  Stock_id:4979
# create  Stock_id:4991
# create  Stock_id:5009
# create  Stock_id:5014
# create  Stock_id:5201
# create  Stock_id:5202
# create  Stock_id:5206
# create  Stock_id:5209
# create  Stock_id:5212
# create  Stock_id:5213
# create  Stock_id:5223
# create  Stock_id:5227
# create  Stock_id:5245
# create  Stock_id:5251
# create  Stock_id:5263
# create  Stock_id:5272
# create  Stock_id:5274
# create  Stock_id:5278
# create  Stock_id:5281
# create  Stock_id:5287
# create  Stock_id:5289
# create  Stock_id:5291
# create  Stock_id:5299
# create  Stock_id:5301
# create  Stock_id:5302
# create  Stock_id:5306
# create  Stock_id:5309
# create  Stock_id:5310
# create  Stock_id:5328
# create  Stock_id:5340
# create  Stock_id:5344
# create  Stock_id:5347
# create  Stock_id:5348
# create  Stock_id:5349
# create  Stock_id:5351
# create  Stock_id:5353
# create  Stock_id:5356
# create  Stock_id:5364
# create  Stock_id:5371
# create  Stock_id:5383
# create  Stock_id:5386
# create  Stock_id:5392
# create  Stock_id:5403
# create  Stock_id:5410
# create  Stock_id:5425
# create  Stock_id:5438
# create  Stock_id:5439
# create  Stock_id:5443
# create  Stock_id:5452
# create  Stock_id:5457
# create  Stock_id:5465
# create  Stock_id:5474
# create  Stock_id:5478
# create  Stock_id:5481
# create  Stock_id:5483
# create  Stock_id:5487
# create  Stock_id:5488
# create  Stock_id:5490
# create  Stock_id:5493
# create  Stock_id:5498
# create  Stock_id:5508
# create  Stock_id:5511
# create  Stock_id:5512
# create  Stock_id:5523
# create  Stock_id:5529
# create  Stock_id:5530
# create  Stock_id:5536
# create  Stock_id:5603
# create  Stock_id:5604
# create  Stock_id:5609
# create  Stock_id:5820
# create  Stock_id:5903
# create  Stock_id:5904
# create  Stock_id:5905
# create  Stock_id:6015
# create  Stock_id:6016
# create  Stock_id:6021
# create  Stock_id:6023
# create  Stock_id:6026
# create  Stock_id:6104
# create  Stock_id:6111
# create  Stock_id:6114
# create  Stock_id:6118
# create  Stock_id:6121
# create  Stock_id:6122
# create  Stock_id:6123
# create  Stock_id:6124
# create  Stock_id:6125
# create  Stock_id:6126
# create  Stock_id:6127
# create  Stock_id:6129
# create  Stock_id:6134
# create  Stock_id:6138
# create  Stock_id:6143
# create  Stock_id:6146
# create  Stock_id:6147
# create  Stock_id:6148
# create  Stock_id:6150
# create  Stock_id:6151
# create  Stock_id:6156
# create  Stock_id:6160
# create  Stock_id:6161
# create  Stock_id:6163
# create  Stock_id:6167
# create  Stock_id:6169
# create  Stock_id:6170
# create  Stock_id:6171
# create  Stock_id:6173
# create  Stock_id:6174
# create  Stock_id:6175
# create  Stock_id:6180
# create  Stock_id:6182
# create  Stock_id:6185
# create  Stock_id:6186
# create  Stock_id:6187
# create  Stock_id:6188
# create  Stock_id:6190
# create  Stock_id:6195
# create  Stock_id:006201
# create  Stock_id:6203
# create  Stock_id:6204
# create  Stock_id:6207
# create  Stock_id:6208
# create  Stock_id:6210
# create  Stock_id:6217
# create  Stock_id:6219
# create  Stock_id:6220
# create  Stock_id:6221
# create  Stock_id:6223
# create  Stock_id:6227
# create  Stock_id:6229
# create  Stock_id:6231
# create  Stock_id:6233
# create  Stock_id:6234
# create  Stock_id:6237
# create  Stock_id:6238
# create  Stock_id:6240
# create  Stock_id:6244
# create  Stock_id:6245
# create  Stock_id:6248
# create  Stock_id:6261
# create  Stock_id:6265
# create  Stock_id:6266
# create  Stock_id:6274
# create  Stock_id:6275
# create  Stock_id:6276
# create  Stock_id:6279
# create  Stock_id:6284
# create  Stock_id:6290
# create  Stock_id:6292
# create  Stock_id:6294
# create  Stock_id:6411
# create  Stock_id:6426
# create  Stock_id:6432
# create  Stock_id:6435
# create  Stock_id:6438
# create  Stock_id:6441
# create  Stock_id:6446
# create  Stock_id:6457
# create  Stock_id:6461
# create  Stock_id:6462
# create  Stock_id:6469
# create  Stock_id:6470
# create  Stock_id:6472
# create  Stock_id:6485
# create  Stock_id:6486
# create  Stock_id:6488
# create  Stock_id:6492
# create  Stock_id:6494
# create  Stock_id:6496
# create  Stock_id:6499
# create  Stock_id:6506
# create  Stock_id:6509
# create  Stock_id:6510
# create  Stock_id:6512
# create  Stock_id:6514
# create  Stock_id:6523
# create  Stock_id:6527
# create  Stock_id:6532
# create  Stock_id:6535
# create  Stock_id:6538
# create  Stock_id:6547
# create  Stock_id:6548
# create  Stock_id:6560
# create  Stock_id:6561
# create  Stock_id:6568
# create  Stock_id:6569
# create  Stock_id:6570
# create  Stock_id:6576
# create  Stock_id:6589
# create  Stock_id:6596
# create  Stock_id:6609
# create  Stock_id:6612
# create  Stock_id:6613
# create  Stock_id:6640
# create  Stock_id:6643
# create  Stock_id:6649
# create  Stock_id:6662
# create  Stock_id:6664
# create  Stock_id:6667
# create  Stock_id:6679
# create  Stock_id:6683
# create  Stock_id:6690
# create  Stock_id:6697
# create  Stock_id:6716
# create  Stock_id:6803
# create  Stock_id:8024
# create  Stock_id:8027
# create  Stock_id:8034
# create  Stock_id:8038
# create  Stock_id:8040
# create  Stock_id:8042
# create  Stock_id:8043
# create  Stock_id:8044
# create  Stock_id:8048
# create  Stock_id:8049
# create  Stock_id:8050
# create  Stock_id:8054
# create  Stock_id:8059
# create  Stock_id:8064
# create  Stock_id:8066
# create  Stock_id:8068
# create  Stock_id:8069
# create  Stock_id:8071
# create  Stock_id:8074
# create  Stock_id:8076
# create  Stock_id:8083
# create  Stock_id:8085
# create  Stock_id:8086
# create  Stock_id:8088
# create  Stock_id:8091
# create  Stock_id:8096
# create  Stock_id:8109
# create  Stock_id:8111
# create  Stock_id:8121
# create  Stock_id:8147
# create  Stock_id:8155
# create  Stock_id:8171
# create  Stock_id:8176
# create  Stock_id:8182
# create  Stock_id:8183
# create  Stock_id:8234
# create  Stock_id:8240
# create  Stock_id:8255
# create  Stock_id:8279
# create  Stock_id:8287
# create  Stock_id:8289
# create  Stock_id:8299
# create  Stock_id:8342
# create  Stock_id:8349
# create  Stock_id:8358
# create  Stock_id:8383
# create  Stock_id:8390
# create  Stock_id:8403
# create  Stock_id:8406
# create  Stock_id:8409
# create  Stock_id:8410
# create  Stock_id:8415
# create  Stock_id:8416
# create  Stock_id:8421
# create  Stock_id:8424
# create  Stock_id:8431
# create  Stock_id:8433
# create  Stock_id:8435
# create  Stock_id:8436
# create  Stock_id:8437
# create  Stock_id:8440
# create  Stock_id:8444
# create  Stock_id:8446
# create  Stock_id:8450
# create  Stock_id:8472
# create  Stock_id:8476
# create  Stock_id:8477
# create  Stock_id:8489
# create  Stock_id:8916
# create  Stock_id:8916A
# create  Stock_id:8924
# create  Stock_id:8928
# create  Stock_id:8929
# create  Stock_id:8932
# create  Stock_id:8933
# create  Stock_id:8935
# create  Stock_id:8936
# create  Stock_id:8938
# create  Stock_id:8942
# create  Stock_id:9949
# create  Stock_id:9951
# create  Stock_id:020001
# create  Stock_id:020003
# create  Stock_id:020010
# create  Stock_id:020013
# create  Stock_id:020014
# create  Stock_id:1563
# create  Stock_id:2246
# create  Stock_id:3633
# create  Stock_id:4151
# create  Stock_id:4195
# create  Stock_id:4431
# create  Stock_id:4565
# create  Stock_id:5222
# create  Stock_id:6595
# create  Stock_id:6598
# create  Stock_id:6634
# create  Stock_id:6645
# create  Stock_id:6665
# create  Stock_id:6692
# create  Stock_id:6732
# create  Stock_id:6736
# create  Stock_id:8119
# create  Stock_id:8179
# create  Stock_id:8438
# Finish <class 'crawlers.models.StockTiiTW'>date:2020-04-29T00:00:00.000000000 bulk_create:1716
# Finish <class 'crawlers.models.StockTiiTW'>date:2020-04-29T00:00:00.000000000 bulk_update:0
