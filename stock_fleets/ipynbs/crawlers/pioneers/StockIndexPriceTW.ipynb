# %%
import sys,os
sys.path.append("..")
import django
django.setup()
import pandas as pd
from io import StringIO
import requests
import datetime
pd.set_option("display.max_rows", None)

# %%
class CrawlStockIndexPriceTW:
    def __init__(self, date):
        self.date = date
        self.date_str = date.strftime("%Y%m%d")
        self.target_name = "台股指數資訊"
        self.sub_market = ["sii", "otc"]

    def crawl_sii(self):

        r = requests.post('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + self.date_str + '&type=IND')

        content = r.text.replace('=', '')
        lines = content.split('\n')
        lines = list(filter(lambda l:len(l.split('",')) > 5, lines))
        content = "\n".join(lines)
        if content == '':
            return None
        df = pd.read_csv(StringIO(content))
        df = df.astype(str)
        df = df.apply(lambda s: s.str.replace(',', ''))
        df = df.rename(columns={'指數':'stock_id','收盤指數':'index_price',
                                '漲跌百分比(%)':'quote_change'})
        df['date'] = pd.to_datetime(self.date).date()
        df['stock_id']=df['stock_id'].apply(lambda s:'上市'+s)
        df[['index_price','quote_change']]=df[['index_price','quote_change']].apply(lambda s:pd.to_numeric(s, errors='coerce'))

        df_all=df.loc[:,['stock_id','date','index_price','quote_change']]
        df_all=df_all.dropna()

        return df_all

    def crawl_otc(self):

        y = str(int(self.date.strftime("%Y")) - 1911)
        date_str = y + "/" + self.date.strftime("%m") + "/" + self.date.strftime("%d")
        link = 'http://www.tpex.org.tw/web/stock/aftertrading/index_summary/summary_download.php?l=zh-tw&d='+date_str+'&s=0,asc,0'
        r = requests.get(link)        

        lines = r.text.replace("\r", "").split("\n")
        try:
            df = pd.read_csv(StringIO("\n".join(lines[3:])), header=None)
        except pd.errors.ParserError:
            return None
        df.columns = list(map(lambda s: s.replace(" ", ""), lines[2].split(",")))
        df = df.apply(lambda s: s.str.replace(",", ""))

        df['stock_id']='上櫃'+(df['指數'].apply(lambda s: s.replace('指數', '')))+'指數'

        #第二個櫃買指數以下的才是報酬指數，找出第二個，各年指數項目不同使用find來定位
        rem_loc=df['指數'].str.find('櫃買指數')
        rem_loc=(rem_loc[rem_loc>-1].index.tolist())[-1]

        #一般指數
        df_normal=df.iloc[:rem_loc]
        #報酬指數
        df_rem=df.copy()
        df_rem=df_rem.iloc[rem_loc:]
        df_rem['stock_id']=df_rem['stock_id'].apply(lambda s: s.replace('指數', '報酬指數'))
#         合併
        df_all=pd.concat([df_normal,df_rem])
        df_all= df_all.rename(columns={'收市指數':'index_price','漲跌幅度':'quote_change'})
        df_all[['index_price','quote_change']]=df_all[['index_price','quote_change']].apply(lambda s:pd.to_numeric(s, errors='coerce'))
        df_all['date'] = pd.to_datetime(self.date).date()
        df_all=df_all.loc[:,['stock_id','date','index_price','quote_change']]
        df_all=df_all.dropna()
        return df_all
        
    def crawl_main(self):
        try:
            df = pd.concat([self.crawl_sii(), self.crawl_otc()])
        except ValueError:
            return None
        return df
   
    
    
z=CrawlStockIndexPriceTW(datetime.datetime(2020,4,16)).crawl_otc()   
z
# Out:
#            stock_id        date  index_price  quote_change
# 0          上櫃化學工業指數  2020-04-16        80.88          0.07
# 1         上櫃文化創意業指數  2020-04-16        98.62         -0.05
# 2          上櫃半導體業指數  2020-04-16        66.48         -0.20
# 3          上櫃生技醫療指數  2020-04-16       102.88          1.61
# 4           上櫃光電業指數  2020-04-16        18.77          1.35
# 5            上櫃其他指數  2020-04-16        85.46          0.41
# 6         上櫃其他電子業指數  2020-04-16        94.06          0.71
# 7          上櫃建材營造指數  2020-04-16       118.63         -0.62
# 8          上櫃紡織纖維指數  2020-04-16        85.35         -0.45
# 9           上櫃航運業指數  2020-04-16        71.74          0.94
# 10         上櫃高殖利率指數  2020-04-16       121.24          0.07
# 11        上櫃通信網路業指數  2020-04-16        72.37          0.36
# 12       上櫃勞工就業88指數  2020-04-16       112.02         -0.10
# 13        上櫃富櫃200指數  2020-04-16      5425.29          0.47
# 14         上櫃富櫃50指數  2020-04-16       161.35          0.04
# 15        上櫃資訊服務業指數  2020-04-16        89.32          1.75
# 16         上櫃電子工業指數  2020-04-16       201.87          0.37
# 17        上櫃電子通路業指數  2020-04-16        51.01          1.47
# 18       上櫃電子零組件業指數  2020-04-16        75.38          1.63
# 19     上櫃電腦及週邊設備業指數  2020-04-16        69.28          0.07
# 20         上櫃電機機械指數  2020-04-16       112.98          0.15
# 21        上櫃臺灣IPO指數  2020-04-16      4828.86         -1.00
# 22    上櫃臺灣中小型公司治理指數  2020-04-16      5209.94         -0.03
# 23         上櫃臺灣生技指數  2020-04-16      3741.98          0.94
# 24       上櫃線上遊戲業類指數  2020-04-16       145.79          0.54
# 25         上櫃鋼鐵工業指數  2020-04-16       117.59         -0.21
# 26       上櫃櫃買公司治理指數  2020-04-16       116.01         -0.35
# 27           上櫃櫃買指數  2020-04-16       130.67          0.39
# 28         上櫃櫃買薪酬指數  2020-04-16        72.33         -0.07
# 29         上櫃觀光事業指數  2020-04-16        59.31         -0.47
# 32         上櫃櫃買報酬指數  2020-04-16       199.37          0.40
# 33      上櫃富櫃200報酬指數  2020-04-16      5635.68          0.47
# 34       上櫃富櫃50報酬指數  2020-04-16       226.83          0.04
# 35       上櫃高殖利率報酬指數  2020-04-16       162.12          0.07
# 36     上櫃勞工就業88報酬指數  2020-04-16       141.93         -0.09
# 37       上櫃櫃買薪酬報酬指數  2020-04-16        86.44         -0.05
# 38     上櫃櫃買公司治理報酬指數  2020-04-16       139.88         -0.33
# 39       上櫃臺灣生技報酬指數  2020-04-16      3935.23          0.94
# 40  上櫃臺灣中小型公司治理報酬指數  2020-04-16      5987.09         -0.03
# 41      上櫃臺灣IPO報酬指數  2020-04-16      5138.38         -1.00
# 42     上櫃台灣5G報酬報酬指數  2020-04-16      4681.03         -0.61
# 43       上櫃紡織纖維報酬指數  2020-04-16       101.10         -0.45
# 44       上櫃電機機械報酬指數  2020-04-16       131.86          0.15
# 45       上櫃鋼鐵工業報酬指數  2020-04-16       134.95         -0.21
# 46       上櫃電子工業報酬指數  2020-04-16       231.98          0.37
# 47       上櫃建材營造報酬指數  2020-04-16       144.32         -0.61
# 48        上櫃航運業報酬指數  2020-04-16        88.64          0.95
# 49       上櫃觀光事業報酬指數  2020-04-16        66.12         -0.48
# 50         上櫃其他報酬指數  2020-04-16        96.14          0.41
# 51       上櫃化學工業報酬指數  2020-04-16        92.32          0.07
# 52       上櫃生技醫療報酬指數  2020-04-16       109.27          1.62
# 53       上櫃半導體業報酬指數  2020-04-16        75.44         -0.20
# 54   上櫃電腦及週邊設備業報酬指數  2020-04-16        84.02          0.07
# 55        上櫃光電業報酬指數  2020-04-16        21.43          1.32
# 56      上櫃通信網路業報酬指數  2020-04-16        82.98          0.36
# 57     上櫃電子零組件業報酬指數  2020-04-16        86.88          1.63
# 58      上櫃電子通路業報酬指數  2020-04-16        55.99          1.49
# 59      上櫃資訊服務業報酬指數  2020-04-16       100.97          1.74
# 60      上櫃其他電子業報酬指數  2020-04-16       104.80          0.72
# 61      上櫃文化創意業報酬指數  2020-04-16       109.48          0.17
# 62     上櫃線上遊戲業類報酬指數  2020-04-16       160.67          0.54

# %%
a={'s':1}
len(a)
# Out:
# 1
