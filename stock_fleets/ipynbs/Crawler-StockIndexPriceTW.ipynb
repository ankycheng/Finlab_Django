# %%
import sys,os
sys.path.append("..")
import django
django.setup()
import pandas as pd
from io import StringIO
import requests
import datetime

# %%
class CrawlStockIndexPriceTW:
    def __init__(self, date):
        self.date = date
        self.date_str = date.strftime("%Y%m%d")
        self.target_name = "台股指數資訊"
        self.sub_market = ["sii", "otc"]

    def sii_index(self):

        r = requests.post('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + self.date_str + '&type=IND')

        content = r.text.replace('=', '')
        lines = content.split('\n')
        lines = list(filter(lambda l:len(l.split('",')) > 5, lines))
        content = "\n".join(lines)
        if content == '':
            return None
        df = pd.read_csv(StringIO(content))
        df = df.astype(str)
        df = df.apply(lambda s: s.str.replace(',', ''))
        df = df.rename(columns={'指數':'stock_id','收盤指數':'index_price',
                                '漲跌百分比(%)':'quote_change'})
        df['date'] = pd.to_datetime(self.date).date()
        df['stock_id']=df['stock_id'].apply(lambda s:'上市'+s)
        df.loc[:,['index_price','quote_change']]=df.loc[:,['index_price','quote_change']].apply(lambda s:pd.to_numeric(s, errors='coerce'))

        df_all=df.loc[:,['stock_id','date','index_price','quote_change']]
        df_all=df_all.dropna()

        return df_all

    def otc_index(self):

        y = str(int(self.date.strftime("%Y")) - 1911)
        date_str = y + "/" + self.date.strftime("%m") + "/" + self.date.strftime("%d")
        link = 'http://www.tpex.org.tw/web/stock/aftertrading/index_summary/summary_download.php?l=zh-tw&d='+date_str+'&s=0,asc,0'
        r = requests.get(link)        

        lines = r.text.replace("\r", "").split("\n")
        try:
            df = pd.read_csv(StringIO("\n".join(lines[3:])), header=None)
        except pd.errors.ParserError:
            return None
        df.columns = list(map(lambda s: s.replace(" ", ""), lines[2].split(",")))
        df = df.apply(lambda s: s.str.replace(",", ""))

        df['stock_id']='上櫃'+(df['指數'].apply(lambda s: s.replace('指數', '')))+'指數'

        #第二個櫃買指數以下的才是報酬指數，找出第二個，各年指數項目不同使用find來定位
        rem_loc=df['指數'].str.find('櫃買指數')
        rem_loc=(rem_loc[rem_loc>-1].index.tolist())[-1]

        #一般指數
        df_normal=df.iloc[:rem_loc]
        #報酬指數
        df_rem=df.iloc[rem_loc:]

        #合併
        df_all=pd.concat([df_normal,df_rem])
        df_all= df_all.rename(columns={'收市指數':'index_price','漲跌幅度':'quote_change'})
        df_all.loc[:,['index_price','quote_change']]=df_all.loc[:,['index_price','quote_change']].apply(lambda s:pd.to_numeric(s, errors='coerce'))
        df_all['date'] = pd.to_datetime(self.date).date()
        df_all=df_all.loc[:,['stock_id','date','index_price','quote_change']]
        df_all=df_all.dropna()
        return df_all
        
    def crawl_main(self):
        try:
            df = pd.concat([self.sii_index(), self.otc_index()])
        except ValueError:
            return None
        return df
   
    
    
z=CrawlStockIndexPriceTW(datetime.datetime(2009,1,6)).crawl_main()   
z
# Out:
#           stock_id       date  index_price  quote_change
# 0      上市發行量加權股價指數 2009-01-06      4727.26          0.62
# 1         上市臺灣50指數 2009-01-06      3441.21          0.39
# 2      上市臺灣中型100指數 2009-01-06      3907.98          1.30
# 3       上市臺灣資訊科技指數 2009-01-06      4118.34          0.44
# 4         上市臺灣發達指數 2009-01-06      4032.76          1.56
# 5        上市臺灣高股息指數 2009-01-06      3423.37          1.35
# 6      上市未含金融保險股指數 2009-01-06      3934.88          0.97
# 7        上市未含電子股指數 2009-01-06      7011.89          0.80
# 8      上市未含金融電子股指數 2009-01-06      5921.49          1.80
# 9        上市水泥窯製類指數 2009-01-06       360.05         -0.36
# 10       上市塑膠化工類指數 2009-01-06       392.57          2.32
# 11         上市機電類指數 2009-01-06      1016.24          0.46
# 12         上市水泥類指數 2009-01-06        90.86         -0.53
# 13         上市食品類指數 2009-01-06       460.82          0.15
# 14         上市塑膠類指數 2009-01-06       116.26          2.88
# 15       上市紡織纖維類指數 2009-01-06       220.32          4.02
# 16       上市電機機械類指數 2009-01-06        49.12          0.27
# 17       上市電器電纜類指數 2009-01-06        26.77          2.61
# 18     上市化學生技醫療類指數 2009-01-06        60.07          0.84
# 19         上市化學類指數 2009-01-06        59.75          1.36
# 20       上市生技醫療類指數 2009-01-06        47.71         -0.85
# 21       上市玻璃陶瓷類指數 2009-01-06        37.92          0.42
# 22         上市造紙類指數 2009-01-06        96.49          0.75
# 23         上市鋼鐵類指數 2009-01-06        80.28          2.65
# 24         上市橡膠類指數 2009-01-06       100.00          0.87
# 25         上市汽車類指數 2009-01-06        52.24          0.06
# 26         上市電子類指數 2009-01-06       181.98          0.45
# 27        上市半導體類指數 2009-01-06        48.16          0.21
# 28    上市電腦及週邊設備類指數 2009-01-06        50.21          0.40
# 29         上市光電類指數 2009-01-06        36.96          2.70
# ..             ...        ...          ...           ...
# 47       上市水泥類報酬指數 2009-01-06        90.86         -0.53
# 48       上市食品類報酬指數 2009-01-06       460.82          0.15
# 49       上市塑膠類報酬指數 2009-01-06       116.26          2.88
# 50     上市紡織纖維類報酬指數 2009-01-06       220.32          4.02
# 51     上市電機機械類報酬指數 2009-01-06        49.12          0.27
# 52     上市電器電纜類報酬指數 2009-01-06        26.77          2.61
# 53   上市化學生技醫療類報酬指數 2009-01-06        60.07          0.84
# 54       上市化學類報酬指數 2009-01-06        59.75          1.36
# 55     上市生技醫療類報酬指數 2009-01-06        47.71         -0.85
# 56     上市玻璃陶瓷類報酬指數 2009-01-06        37.92          0.42
# 57       上市造紙類報酬指數 2009-01-06        96.49          0.75
# 58       上市鋼鐵類報酬指數 2009-01-06        80.28          2.65
# 59       上市橡膠類報酬指數 2009-01-06       100.00          0.87
# 60       上市汽車類報酬指數 2009-01-06        52.24          0.06
# 61       上市電子類報酬指數 2009-01-06       203.96          0.44
# 62      上市半導體類報酬指數 2009-01-06        51.78          0.19
# 63  上市電腦及週邊設備類報酬指數 2009-01-06        54.86          0.40
# 64       上市光電類報酬指數 2009-01-06        39.03          2.71
# 65     上市通信網路類報酬指數 2009-01-06        89.98         -1.34
# 66    上市電子零組件類報酬指數 2009-01-06        43.24          1.60
# 67     上市電子通路類報酬指數 2009-01-06        55.34          3.69
# 68     上市資訊服務類報酬指數 2009-01-06        75.09         -0.70
# 69     上市其他電子類報酬指數 2009-01-06        36.82          1.27
# 70     上市建材營造類報酬指數 2009-01-06       123.04         -0.66
# 71       上市航運類報酬指數 2009-01-06        68.55          3.72
# 72       上市觀光類報酬指數 2009-01-06        92.23         -3.05
# 73     上市金融保險類報酬指數 2009-01-06       655.58         -1.41
# 74     上市貿易百貨類報酬指數 2009-01-06        94.83          0.30
# 75     上市油電燃氣類報酬指數 2009-01-06        84.65          2.18
# 76       上市其他類報酬指數 2009-01-06        81.54          0.26
#
# [74 rows x 4 columns]
